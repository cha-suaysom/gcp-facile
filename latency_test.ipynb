# %% [markdown]
# Latency test from a VM cha-gpu in us-central1-a to the cluster service internet2-test in us-central1-a

# %%
import logging
import grpc
import time
import numpy as np
import pandas as pd
import server_tools_pb2
import server_tools_pb2_grpc
from google.protobuf import empty_pb2
from matplotlib import pyplot as plt

PORT = '50051'

def run_facile(channel, data_send, num_data_send, batch_size):
    start_time = time.time()
    
    # Get a client ID which you need to talk to the server
    stub = server_tools_pb2_grpc.FacileServerStub(channel)
    try:
        response = stub.RequestClientID(server_tools_pb2.NullParam())
    except BaseException:
        print(
             """Connection to the server could not be established.
             Press enter to try again.""")
        return
    client_id = response.new_id
    finish_time = time.time()-start_time

    start_time = time.time()
    data_message = server_tools_pb2.DataMessage(
        client_id=client_id, data=data_send, batch_size=batch_size, num_data = num_data_send)
    response = stub.StartJobWait(data_message, 100, [])
    
    whole_time = time.time() - start_time
    server_time = response.server_time
    latency_time = whole_time-server_time
    latency_percentage = (1 -server_time / whole_time) * 100
    
    A = np.frombuffer(response.prediction,dtype = np.float32)
    print(list(np.frombuffer(response.prediction,dtype = np.float32))[:10])
    channel.close()
    return response.infer_time_CPU, response.infer_time_GPU, whole_time, latency_time, latency_percentage


def setup_server(host_IP):
    options = [('grpc.max_receive_message_length', 500*1024*1024 )]
    channel = grpc.insecure_channel(host_IP + ':' + PORT, options = options)
    return channel

# %%
logging.basicConfig()
logging.root.setLevel(logging.NOTSET)
logging.basicConfig(level=logging.NOTSET)

start_time = time.time()
read_rec_hit = pd.read_pickle("input/X_HB.pkl")
read_rec_hit.drop(['PU', 'pt'], 1, inplace=True)
mu,std = np.mean(read_rec_hit, axis=0), np.std(read_rec_hit, axis=0)
read_rec_hit = (read_rec_hit-mu)/std

read_rec_hit = pd.concat([read_rec_hit]*100, ignore_index=True)

# %%
IP = "35.232.67.41"
n_event = 16000
gpu_time_list = []
latency_time_list = []
num_data_send_list = n_event*(2*(np.arange(20)+1))

for num_data_send in num_data_send_list:
    read_rec_hit_sliced = read_rec_hit[:num_data_send]
    num_data_send = len(read_rec_hit_sliced)
    start_time = time.time()
    compressed_data = read_rec_hit_sliced.values.tobytes()
    finish_time = time.time()-start_time
    print("Time reading data from local file (pandas->bytes) is ", finish_time)
    print(num_data_send)
    cpu_time, gpu_time, whole_time, latency_time, latency_percentage = run_facile(setup_server(IP), compressed_data, num_data_send, int(num_data_send/4))
    print("CPU TIME :", cpu_time*(1e9)/len(read_rec_hit_sliced), "ns per hit")
    #print("CPU TIME :", cpu_time*(1e3)*n_event/len(read_rec_hit_sliced), "ms per event") 
    gpu_time_list.append(gpu_time*(1e9)/len(read_rec_hit_sliced))
    print("GPU TIME :", gpu_time*(1e9)/len(read_rec_hit_sliced), "ns per hit")
    #print("GPU TIME :", gpu_time*(1e3)*n_event/len(read_rec_hit_sliced), "ms per event")  
    print("Whole time :", whole_time*(1e9)/len(read_rec_hit_sliced), "ns per hit")
    latency_time_list.append(latency_percentage)
    print("Latency time", latency_time*(1e9)/len(read_rec_hit_sliced), "ns per hit")
    print("Latency percentage", latency_percentage , '%')
# Out:
# Time reading data from local file (pandas->bytes) is  0.00482487678527832
# 32000
# [0.19782662, 0.95505786, 31.810246, 1.0363286, 4.350487, 4.136828, 0.23492703, 23.075493, 3.4669788, 0.13345513]
# CPU TIME : 1101.262867450714 ns per hit
# GPU TIME : 211.0004425048828 ns per hit
# Whole time : 19584.618508815765 ns per hit
# Latency time 12545.250356197357 ns per hit
# Latency percentage 64.05664910220372 %
# Time reading data from local file (pandas->bytes) is  0.003871917724609375
# 64000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 5279.7831594944 ns per hit
# GPU TIME : 189.36768174171448 ns per hit
# Whole time : 32973.92651438713 ns per hit
# Latency time 8131.872862577438 ns per hit
# Latency percentage 24.661524186479134 %
# Time reading data from local file (pandas->bytes) is  0.006284952163696289
# 96000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 3591.3512110710144 ns per hit
# GPU TIME : 174.88996187845865 ns per hit
# Whole time : 21952.641506989796 ns per hit
# Latency time 5396.194756031036 ns per hit
# Latency percentage 24.581072643640034 %
# Time reading data from local file (pandas->bytes) is  0.008279085159301758
# 128000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 385.0068897008896 ns per hit
# GPU TIME : 164.6094024181366 ns per hit
# Whole time : 6467.163562774658 ns per hit
# Latency time 4620.706662535667 ns per hit
# Latency percentage 71.4487366475885 %
# Time reading data from local file (pandas->bytes) is  0.010143041610717773
# 160000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 353.3661365509033 ns per hit
# GPU TIME : 166.65607690811157 ns per hit
# Whole time : 5722.5629687309265 ns per hit
# Latency time 4087.8117084503174 ns per hit
# Latency percentage 71.43323246571208 %
# Time reading data from local file (pandas->bytes) is  0.012302160263061523
# 192000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 326.7340362071991 ns per hit
# GPU TIME : 154.30028239885965 ns per hit
# Whole time : 5127.505709727605 ns per hit
# Latency time 3722.0542629559836 ns per hit
# Latency percentage 72.58995842549174 %
# Time reading data from local file (pandas->bytes) is  0.013994216918945312
# 224000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 1613.1347843578883 ns per hit
# GPU TIME : 156.75063644136702 ns per hit
# Whole time : 11137.84738949367 ns per hit
# Latency time 3683.1083042281016 ns per hit
# Latency percentage 33.068403394558786 %
# Time reading data from local file (pandas->bytes) is  0.01928567886352539
# 256000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 244.8754385113716 ns per hit
# GPU TIME : 136.8597149848938 ns per hit
# Whole time : 5031.9647416472435 ns per hit
# Latency time 3974.459134042263 ns per hit
# Latency percentage 78.98424051240869 %
# Time reading data from local file (pandas->bytes) is  0.03405499458312988
# 288000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 296.3137295511034 ns per hit
# GPU TIME : 183.25944741566977 ns per hit
# Whole time : 4389.086531268225 ns per hit
# Latency time 3226.3100147247314 ns per hit
# Latency percentage 73.50755087055643 %
# Time reading data from local file (pandas->bytes) is  0.03872489929199219
# 320000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 258.2445740699768 ns per hit
# GPU TIME : 154.45947647094727 ns per hit
# Whole time : 4152.455925941467 ns per hit
# Latency time 3036.4029109477997 ns per hit
# Latency percentage 73.12306175192865 %
# Time reading data from local file (pandas->bytes) is  0.022070884704589844
# 352000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 257.28954510255295 ns per hit
# GPU TIME : 154.11458232186058 ns per hit
# Whole time : 3926.1870763518596 ns per hit
# Latency time 2913.9952226118608 ns per hit
# Latency percentage 74.21946957554277 %
# Time reading data from local file (pandas->bytes) is  0.0254361629486084
# 384000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 231.05678459008536 ns per hit
# GPU TIME : 157.2743058204651 ns per hit
# Whole time : 3513.5019570589066 ns per hit
# Latency time 2616.794779896736 ns per hit
# Latency percentage 74.47825024373151 %
# Time reading data from local file (pandas->bytes) is  0.05066967010498047
# 416000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 233.00773822344266 ns per hit
# GPU TIME : 154.10322409409744 ns per hit
# Whole time : 3726.774683365455 ns per hit
# Latency time 2866.111695766449 ns per hit
# Latency percentage 76.90595593448148 %
# Time reading data from local file (pandas->bytes) is  0.05115699768066406
# 448000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 216.98112998689925 ns per hit
# GPU TIME : 143.25657061168127 ns per hit
# Whole time : 4027.873809848513 ns per hit
# Latency time 3226.64635522025 ns per hit
# Latency percentage 80.10793057445866 %
# Time reading data from local file (pandas->bytes) is  0.05722761154174805
# 480000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 241.65809154510498 ns per hit
# GPU TIME : 154.18032805124918 ns per hit
# Whole time : 3333.774209022522 ns per hit
# Latency time 2503.7636359532676 ns per hit
# Latency percentage 75.1029757557391 %
# Time reading data from local file (pandas->bytes) is  0.060659170150756836
# 512000
# [0.19782662, 0.95505774, 31.810242, 1.0363286, 4.3504868, 4.1368275, 0.234927, 23.075493, 3.4669785, 0.13345513]
# CPU TIME : 213.65098655223846 ns per hit
# GPU TIME : 154.88360077142715 ns per hit
# Whole time : 3179.093822836876 ns per hit
# Latency time 2398.0392143130302 ns per hit
# Latency percentage 75.43153325915783 %
# Time reading data from local file (pandas->bytes) is  0.06422948837280273
# 544000
# [0.19782665, 0.95505774, 31.810246, 1.0363286, 4.3504868, 4.1368265, 0.23492695, 23.075493, 3.4669783, 0.13345513]
# CPU TIME : 219.89643573760986 ns per hit
# GPU TIME : 158.9796122382669 ns per hit
# Whole time : 3158.6118480738473 ns per hit
# Latency time 2382.5729594511145 ns per hit
# Latency percentage 75.43101444718606 %
# Time reading data from local file (pandas->bytes) is  0.06954240798950195
# 576000
# [0.19782665, 0.95505774, 31.810246, 1.0363286, 4.3504868, 4.1368265, 0.23492695, 23.075493, 3.4669783, 0.13345513]
# CPU TIME : 189.26006224420337 ns per hit
# GPU TIME : 153.36482061280145 ns per hit
# Whole time : 3763.3209592766234 ns per hit
# Latency time 3067.8659677505493 ns per hit
# Latency percentage 81.52017861214387 %
# Time reading data from local file (pandas->bytes) is  0.07233810424804688
# 608000
# [0.19782665, 0.95505774, 31.810246, 1.0363286, 4.3504868, 4.1368265, 0.23492695, 23.075493, 3.4669783, 0.13345513]
# CPU TIME : 217.51617130480315 ns per hit
# GPU TIME : 151.93812156978407 ns per hit
# Whole time : 2994.4252026708505 ns per hit
# Latency time 2236.052171180123 ns per hit
# Latency percentage 74.67383620688526 %
# Time reading data from local file (pandas->bytes) is  0.07617020606994629
# 640000
# [0.19782665, 0.95505774, 31.810246, 1.0363286, 4.3504868, 4.1368265, 0.23492695, 23.075493, 3.4669783, 0.13345513]
# CPU TIME : 211.7849886417389 ns per hit
# GPU TIME : 150.44920146465302 ns per hit
# Whole time : 2929.292991757393 ns per hit
# Latency time 2219.9176251888275 ns per hit
# Latency percentage 75.78339317491815 %

# %%
#N = 16000
mpl_logger = logging.getLogger("matplotlib")
mpl_logger.setLevel(logging.WARNING)

import matplotlib.ticker as mtick

fig = plt.figure()

ax = fig.add_subplot(111)
num_data_send_list = num_data_send_list/n_event
ax.plot(num_data_send_list, gpu_time_list, 'o', label = 'inference')
ax.plot(num_data_send_list, latency_time_list, 'o', label = 'latency')
ax.legend()
ax.yaxis.set_major_formatter(mtick.FormatStrFormatter('%.2e'))
plt.title("Inference time (ns) and latency vs. number of events ")
plt.show()
