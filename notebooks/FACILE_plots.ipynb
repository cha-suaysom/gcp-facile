# %% [markdown]
# ### FACILE Inference
# The following notebook shows sample graph from the inference using FACILE.

# %% [markdown]
# ### Input Files
# 1. `X_HB.pkl`, `Y_HB.pkl` for the input to FACILE.
# 2. Pre-trained weight files by FACILE team [HB_model_v0.h5](https://github.com/JackDinsmore/FACILE/blob/master/HB_model_v0.h5)

# %% [markdown]
# ### Necessary imports

# %%
import logging
import grpc
import time
import numpy as np
import pandas as pd
import server_tools_pb2
import server_tools_pb2_grpc
from google.protobuf import empty_pb2

# %%
from IPython.display import Image
Image(filename='plots/4layersExpLLLow/DNN_30_pu_60_80_pt_100.png')

# %%
from IPython.display import Image
Image(filename='plots/4layersExpLLLow/M3_30_pu_60_80_pt_100.png')

# %%
from IPython.display import Image
Image(filename='plots/4layersExpLLLow/Mahi_30_pu_60_80_pt_100.png')

# %%
from IPython.display import Image
Image(filename='plots/4layersExpLLLow/resolution_2.png')

# %%
from IPython.display import Image
Image(filename='plots/4layersExpLLLow/response_2.png')

# %%
from IPython.display import Image
Image(filename='plots/4layersExpLLLow/timing.png')
